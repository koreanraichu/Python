# %%
import GEOparse # NCBI GEO에 접근할 때 필요함
import pandas as pd

# %%
# 창고는 열려있다! 데이터를 털어라!
print("--- GSE30219 데이터 다운로드 중... ---")
gse_mut = GEOparse.get_GEO(geo="GSE79021", destdir="./") # 진짜 창고 터는중
df_mut = gse_mut.phenotype_data

df_mut.head()

# %%
df_mut.to_csv('GSE79021.csv', index=False) # CSV로 저장

# %%
df_mut['label_ch1'].value_counts()
