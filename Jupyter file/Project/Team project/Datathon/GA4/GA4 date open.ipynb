# %%
import pandas as pd

# %% [markdown]
# # Demographic

# %%
demographic_df = pd.read_csv('data/20260319_Rextreme_GA4_by_date/Demographic_details_Country_by_date.csv', comment='#')
demographic_df2 = pd.read_csv('data/20260319_Rextreme_GA4_by_date_2/Demographic_region_city_by_date.csv', comment='#')

# %%
demographic_df

# %%
demographic_df2

# %%
demographic_df.isna().sum()

# %%
demographic_df2.isna().sum()

# %%
not_set_counts = (demographic_df == '(not set)').sum()

not_set_counts

# %%
not_set_counts = (demographic_df2 == '(not set)').sum()

not_set_counts

# %%
demographic_df.groupby('Date').size()

# %%
demographic_df2.groupby('Date').size()

# %%
demographic_df2['Region'].value_counts()

# %%
demographic_df2['City'].value_counts()

# %% [markdown]
# # Events

# %%
events_df = pd.read_csv('data/20260319_Rextreme_GA4_by_date/Events_Event_name_by_date.csv', comment='#')

# %%
events_df

# %%
events_df.isna().sum()

# %%
not_set_counts = (events_df == '(not set)').sum()

not_set_counts

# %% [markdown]
# # Landing page

# %%
landing_df = pd.read_csv('data/20260319_Rextreme_GA4_by_date/Landing_page_by_date.csv', comment='#')
landing_df2 = pd.read_csv('data/20260319_Rextreme_GA4_by_date_2/Landing_page_source_medium_by_date.csv', comment='#')

# %%
landing_df

# %%
landing_df2

# %%
landing_df.isna().sum()

# %%
landing_df2.isna().sum()

# %%
not_set_counts = (landing_df == '(not set)').sum()

not_set_counts

# %%
not_set_counts = (landing_df2 == '(not set)').sum()

not_set_counts

# %%
landing_df[landing_df['Landing page'] == '(not set)']

# %% [markdown]
# # Pages

# %%
page_df = pd.read_csv('data/20260319_Rextreme_GA4_by_date/Pages_and_screens_by_date.csv', comment='#')

# %%
page_df

# %%
page_df.isna().sum()

# %%
not_set_counts = (page_df == '(not set)').sum()

not_set_counts

# %% [markdown]
# # tech_df

# %%
tech_df = pd.read_csv('data/20260319_Rextreme_GA4_by_date/Tech_details_Browser_by_date.csv', comment='#')

# %%
tech_df

# %%
tech_df.isna().sum()

# %%
not_set_counts = (tech_df == '(not set)').sum()

not_set_counts

# %% [markdown]
# # Traffic_df

# %%
traffic_df = pd.read_csv('data/20260319_Rextreme_GA4_by_date/Traffic_acquisition_by_date.csv', comment='#')
traffic_df2 = pd.read_csv('data/20260319_Rextreme_GA4_by_date/Traffic_acquisition_source_medium_by_date.csv', comment='#')

# %%
traffic_df

# %%
traffic_df2

# %%
traffic_df.isna().sum()

# %%
traffic_df2.isna().sum()

# %%
not_set_counts = (traffic_df == '(not set)').sum()

not_set_counts

# %%
not_set_counts = (traffic_df2 == '(not set)').sum()

not_set_counts
