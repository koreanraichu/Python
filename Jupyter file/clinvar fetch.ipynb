# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select

# %%
# 웹드라이버 실행
driver = webdriver.Chrome() # 구글 크롬
driver.get('https://www.ncbi.nlm.nih.gov/clinvar/') # Clinvar 접속
print('Clivar Accessed!')
# Out:
# Clivar Accessed!

# %%
go_ftp = driver.find_element(by=By.CSS_SELECTOR, value='#maincontent > div.col1 > div > div:nth-child(1) > div.tier.firsttier > div:nth-child(1) > div > div.portlet_content > ul > li:nth-child(3) > a')
# 아니... 이 셀렉터가 맞는데 왜 가지를 못하니... (결국 다시 복붙했음)

go_ftp.click()

# %%
# vcf_GRCh37
def vcf_37():
    go_vcf = driver.find_element(by=By.CSS_SELECTOR, value='body > pre > a:nth-child(11)')
    go_vcf.click()
    go_vcf_2 = driver.find_element(by=By.CSS_SELECTOR, value='body > pre > a:nth-child(11)')
    go_vcf_2.click()
    print('Download processing...')

# %%
# vcf_GRCh38
def vcf_38():
    go_vcf = driver.find_element(by=By.CSS_SELECTOR, value='body > pre > a:nth-child(12)')
    go_vcf.click()
    go_vcf_2 = driver.find_element(by=By.CSS_SELECTOR, value='body > pre > a:nth-child(11)')
    go_vcf_2.click()
    print('Download processing...')

# %%
vcf_37()
# Out:
# Download processing...
