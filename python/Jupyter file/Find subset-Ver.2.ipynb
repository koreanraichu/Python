# %%
text="AGTCAGTCCGTGATCTAGCTAGCTAG"
print(text)  
# 일단 소규모로 먼저 진행해보자.
# Out:
# AGTCAGTCCGTGATCTAGCTAGCTAG

# %%
# 전체 텍스트를 slicing하는 for문. 이 안에는 찾을 영역과 찾아야 할 영역이 포함되어 있다. 
# 한 글자일때는 찾을 영역이 존재하지만 찾아야 하는 글자가 없으므로 첫 글자는 0이다. 
find_list=[]
length=len(text)
for i in range(1,length+1):
    if len(text[0:i]) == 1: 
        find_list.append(0)
    else:
        text_sub=text[0:i] # 전체 텍스트
        find=text_sub[:i-1]# 찾을 범위 
        max_list=[]
        for j in range(1,len(find)+1):
            subset=text_sub[j:] # 찾을 텍스트
            print(subset)
            find_values=0
            if subset in find:
                max_list.append(len(subset))
            else: 
                max_list.append(0)
            max_list=set(max_list)
            max_list=list(max_list)
            max_values=max(max_list) # 리스트에서 최대값을 추출한다
        find_list.append(max_values) # 넣어주시죠 
# 응? 이거 근데 왜 제시한거랑 다르지?
# Out:
# G
# GT
# T
# GTC
# TC
# C
# GTCA
# TCA
# CA
# A
# GTCAG
# TCAG
# CAG
# AG
# G
# GTCAGT
# TCAGT
# CAGT
# AGT
# GT
# T
# GTCAGTC
# TCAGTC
# CAGTC
# AGTC
# GTC
# TC
# C
# GTCAGTCC
# TCAGTCC
# CAGTCC
# AGTCC
# GTCC
# TCC
# CC
# C
# GTCAGTCCG
# TCAGTCCG
# CAGTCCG
# AGTCCG
# GTCCG
# TCCG
# CCG
# CG
# G
# GTCAGTCCGT
# TCAGTCCGT
# CAGTCCGT
# AGTCCGT
# GTCCGT
# TCCGT
# CCGT
# CGT
# GT
# T
# GTCAGTCCGTG
# TCAGTCCGTG
# CAGTCCGTG
# AGTCCGTG
# GTCCGTG
# TCCGTG
# CCGTG
# CGTG
# GTG
# TG
# G
# GTCAGTCCGTGA
# TCAGTCCGTGA
# CAGTCCGTGA
# AGTCCGTGA
# GTCCGTGA
# TCCGTGA
# CCGTGA
# CGTGA
# GTGA
# TGA
# GA
# A
# GTCAGTCCGTGAT
# TCAGTCCGTGAT
# CAGTCCGTGAT
# AGTCCGTGAT
# GTCCGTGAT
# TCCGTGAT
# CCGTGAT
# CGTGAT
# GTGAT
# TGAT
# GAT
# AT
# T
# GTCAGTCCGTGATC
# TCAGTCCGTGATC
# CAGTCCGTGATC
# AGTCCGTGATC
# GTCCGTGATC
# TCCGTGATC
# CCGTGATC
# CGTGATC
# GTGATC
# TGATC
# GATC
# ATC
# TC
# C
# GTCAGTCCGTGATCT
# TCAGTCCGTGATCT
# CAGTCCGTGATCT
# AGTCCGTGATCT
# GTCCGTGATCT
# TCAGTCCGTGATCTAGCTAGC
# CAGTCCGTGATCTAGCTAGC
# AGTCCGTGATCTAGCTAGC
# GTCCGTGATCTAGCTAGC
# TCCGTGATCTAGCTAGC
# CCGTGATCTAGCTAGC
# CGTGATCTAGCTAGC
# GTGATCTAGCTAGC
# TGATCTAGCTAGC
# GATCTAGCTAGC
# ATCTAGCTAGC
# TCTAGCTAGC
# CTAGCTAGC
# TAGCTAGC
# AGCTAGC
# GCTAGC
# CTAGC
# TAGC
# AGC
# GC
# C
# GTCAGTCCGTGATCTAGCTAGCT
# TCAGTCCGTGATCTAGCTAGCT
# CAGTCCGTGATCTAGCTAGCT
# AGTCCGTGATCTAGCTAGCT
# GTCCGTGATCTAGCTAGCT
# TCCGTGATCTAGCTAGCT
# CCGTGATCTAGCTAGCT
# CGTGATCTAGCTAGCT
# GTGATCTAGCTAGCT
# TGATCTAGCTAGCT
# GATCTAGCTAGCT
# ATCTAGCTAGCT
# TCTAGCTAGCT
# CTAGCTAGCT
# TAGCTAGCT
# AGCTAGCT
# GCTAGCT
# CTAGCT
# TAGCT
# AGCT
# GCT
# CT
# T
# GTCAGTCCGTGATCTAGCTAGCTA
# TCAGTCCGTGATCTAGCTAGCTA
# CAGTCCGTGATCTAGCTAGCTA
# AGTCCGTGATCTAGCTAGCTA
# GTCCGTGATCTAGCTAGCTA
# TCCGTGATCTAGCTAGCTA
# CCGTGATCTAGCTAGCTA
# CGTGATCTAGCTAGCTA
# GTGATCTAGCTAGCTA
# TGATCTAGCTAGCTA
# GATCTAGCTAGCTA
# ATCTAGCTAGCTA
# TCTAGCTAGCTA
# CTAGCTAGCTA
# TAGCTAGCTA
# AGCTAGCTA
# GCTAGCTA
# CTAGCTA
# TAGCTA
# AGCTA
# GCTA
# CTA
# TA
# A
# GTCAGTCCGTGATCTAGCTAGCTAG
# TCAGTCCGTGATCTAGCTAGCTAG
# CAGTCCGTGATCTAGCTAGCTAG
# AGTCCGTGATCTAGCTAGCTAG
# GTCCGTGATCTAGCTAGCTAG
# TCCGTGATCTAGCTAGCTAG
# CCGTGATCTAGCTAGCTAG
# CGTGATCTAGCTAGCTAG
# GTGATCTAGCTAGCTAG
# TGATCTAGCTAGCTAG
# GATCTAGCTAGCTAG
# ATCTAGCTAGCTAG
# TCTAGCTAGCTAG
# CTAGCTAGCTAG
# TAGCTAGCTAG
# AGCTAGCTAG
# GCTAGCTAG
# CTAGCTAG
# TAGCTAG
# AGCTAG
# GCTAG
# CTAG
# TAG
# AG
# G

# %%
find_text=''.join(map(str,find_list))
# 출력할 문자열을 붙여준다. (데이터 저장 형태가 리스트였음)
print(find_text)
# Out:
# 00001234112111211212345678
